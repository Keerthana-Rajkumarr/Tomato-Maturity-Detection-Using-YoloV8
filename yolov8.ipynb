# %%
# !nvidia-smi
# Out:
# Fri Jan 26 17:02:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.7/744.7 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 694.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.1 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 82.8MB/s]
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 13.9MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 103.8ms
# Speed: 14.4ms preprocess, 103.8ms inference, 817.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 300MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Tomato
# Out:
# /content/drive/MyDrive/Tomato

# %%
# !ls
# Out:
# archive  bus.jpg  runs	yolov8.ipynb  yolov8n.pt  yolov8x.pt

# %%
results = model.train(data='/content/drive/MyDrive/Tomato/archive/example_dataset.yaml', epochs=100, imgsz=640, model="yolov8x.pt",batch=16)
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import PIL

# Load a model
custom = YOLO('/content/drive/MyDrive/Tomato/runs/detect/train3/weights/best.pt')  # load a custom model

# Predict with the model
result = custom(save=True, conf=0.5, source="/content/drive/MyDrive/Tomato/archive/val/images/IMG_1066.jpg")  # predict on an image
# Out:
# image 1/1 /content/drive/MyDrive/Tomato/archive/val/images/IMG_1066.jpg: 640x480 3 b_half_ripeneds, 4 b_greens, 91.4ms
# Speed: 12.6ms preprocess, 91.4ms inference, 760.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict9

# %%
from PIL import Image
from IPython.display import display

image = Image.open("/content/drive/MyDrive/Tomato/runs/detect/predict9/IMG_1066.jpg")
desired_size = (700, 600)
image.thumbnail(desired_size)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x600>

# %%
from PIL import Image
from IPython.display import display

# List of image paths
image_paths = [
    "/content/drive/MyDrive/Tomato/runs/detect/train3/P_curve.png",
    "/content/drive/MyDrive/Tomato/runs/detect/train3/R_curve.png",
    "/content/drive/MyDrive/Tomato/runs/detect/train3/PR_curve.png",
]

desired_size = (700, 600)

for image_path in image_paths:

    image = Image.open(image_path)
    image.thumbnail(desired_size)
    display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x467>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x467>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x467>

# %%
from PIL import Image
from IPython.display import display


image_paths = [
    "/content/drive/MyDrive/Tomato/runs/detect/train3/confusion_matrix.png",
    "/content/drive/MyDrive/Tomato/runs/detect/train3/results.png",
    "/content/drive/MyDrive/Tomato/runs/detect/train3/labels.jpg",
]
desired_size = (700, 600)


for image_path in image_paths:
    image = Image.open(image_path)
    image.thumbnail(desired_size)

    display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x525>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x350>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600>
